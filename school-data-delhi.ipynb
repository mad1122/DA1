# %% [markdown]
# ### PROJECT: SCHOOL DATA

# %% [markdown]
# ### Createing a dataset by scraping data from school database website: https://schools.org.in/delhi
# ### Analayse the data gathered after scraping it from different pages within the website
# ### Denoting the key attributes of different schools

# %% [markdown]
# # Importing needed libraries:

# %%
import numpy as np
import pandas as pd
import random
from numpy.random import randn
import os
import seaborn as sn
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import datetime
import pytz
import re
from scipy.stats import stats
import requests
from bs4 import BeautifulSoup as bs

# %% [markdown]
# **Using requests to download webpage with data**

# %%
Delhi_Districts_url='https://github.com/topics'
distt= requests.get(Delhi_Districts_url)

# %%
distt.status_code
